# %%
module r_mod

export normal_dist
function normal_dist()
        randn(1000)
end

end
# Out:
# WARNING: replacing module r_mod.
# Main.r_mod

# %%
using .r_mod
using Plots

# %%
x = r_mod.normal_dist()

histogram(x)
